# %%
import spacy
from spacy.tokens import DocBin
from tqdm import tqdm
from transformers import pipeline
from collections import defaultdict

# %%
model = pipeline('fill-mask', model='bert-base-uncased')
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
pred = model("I love pizza and [MASK].")
pred
# Out:
# [{'score': 0.18336044251918793,
#   'token': 10733,
#   'token_str': 'pizza',
#   'sequence': 'i love pizza and pizza.'},
#  {'score': 0.12329741567373276,
#   'token': 5404,
#   'token_str': 'beer',
#   'sequence': 'i love pizza and beer.'},
#  {'score': 0.050967153161764145,
#   'token': 4511,
#   'token_str': 'wine',
#   'sequence': 'i love pizza and wine.'},
#  {'score': 0.045108597725629807,
#   'token': 24857,
#   'token_str': 'pasta',
#   'sequence': 'i love pizza and pasta.'},
#  {'score': 0.03131162002682686,
#   'token': 8808,
#   'token_str': 'cheese',
#   'sequence': 'i love pizza and cheese.'}]

# %%
bert_dict = defaultdict(lambda : defaultdict(list))

# %%
with open("subtitles_raw/en_raw_0-900.txt", "rt", encoding="utf-8") as f:
    en_all = [line.strip() for line in f]

with open("subtitles_raw/ru_raw_0-900.txt", "rt", encoding="utf-8") as f:
    ru_all = [line.strip() for line in f]

# %%
with open("corpora/subtitles/ru_subtitles_spacy_dump.bin", "rb") as f:
    restored_bytes_data = f.read()

nlp = spacy.blank("ru")
doc_bin = DocBin().from_bytes(restored_bytes_data)
ru_all_docs = list(doc_bin.get_docs(nlp.vocab))

# %%
with open("corpora/subtitles/en_subtitles_spacy_dump.bin", "rb") as f:
    restored_bytes_data = f.read()

nlp = spacy.blank("en")
doc_bin = DocBin().from_bytes(restored_bytes_data)
en_all_docs = list(doc_bin.get_docs(nlp.vocab))

# %%
with open("corpora/subtitles/translations/opus10_spacy.bin", "rb") as file:
    en_translated_bytes_data = file.read()

nlp = spacy.blank("en")
doc_bin = DocBin().from_bytes(en_translated_bytes_data)
en_translated_docs = list(doc_bin.get_docs(nlp.vocab))

# %%
def find_lines_with_word(original_word: str, docs) -> list:
    indexes = []
    for i, sentence in enumerate(docs):
        for token in sentence:
            if token.lemma_.lower() == original_word:
                indexes.append(i)
                break
    return indexes

# %%
# indexes = []
# for original_word in common:
#     indexes += find_lines_with_word(original_word, ru_all_docs)
# len(indexes)

# %%
def fill_bert_dict_for_one_word(original_word: str, aligned_text: list):
    MASK_TOKEN = '[MASK]'
    bert_word_dict = defaultdict(list)
    for line_idx, ru_doc in tqdm(enumerate(ru_all_docs)):
        if len(aligned_text[line_idx]) == 0:
            continue
        ru_token_idx = -1;
        for j, token in enumerate(ru_doc):
            if token.lemma_.lower() == original_word:
                if ru_token_idx != -1: 
                    ru_token_idx = -1
                    break
                else:
                    ru_token_idx = j
        if ru_token_idx != -1:
            en_token_idx = -1
            en_tokens = [token.text for token in en_all_docs[line_idx]]
            # print(line_idx)
            for src, tgt in aligned_text[line_idx]:
                if src == ru_token_idx:
                    if en_token_idx != -1:
                        en_token_idx = -1
                        break
                    else:
                        en_token_idx = tgt
            if en_token_idx != -1:
                en_tokens[en_token_idx] = MASK_TOKEN
                pred = model(' '.join(en_tokens))
                bert_word_dict[str(line_idx)] = pred
    return bert_word_dict

# %%
with open("corpora/subtitles/numerical_alignment/subtitles_inter.txt", "rt", encoding="utf-8") as file:
    aligned_inter = [[tuple(map(int, pair.split('-'))) for pair in line.strip().split()] for line in file]

with open("corpora/subtitles/numerical_alignment/subtitles_itermax.txt", "rt", encoding="utf-8") as file:
    aligned_itermax = [[tuple(map(int, pair.split('-'))) for pair in line.strip().split()] for line in file]

with open("corpora/subtitles/numerical_alignment/subtitles_mwmf.txt", "rt", encoding="utf-8") as file:
    aligned_mwmf = [[tuple(map(int, pair.split('-'))) for pair in line.strip().split()] for line in file]

# %%
print(aligned_inter[80])
# Out:
# [(0, 0), (1, 1), (2, 3), (3, 4), (4, 5), (5, 6), (6, 8), (8, 9), (9, 10)]

# %%
bert_word_dict = fill_bert_dict_for_one_word("новый", aligned_inter)
bert_word_dict
# Out:
# 900000it [05:33, 2697.69it/s]
# defaultdict(list,
#             {'374': [{'score': 0.2799505293369293,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': "shouldn't you be over there with your new friends?"},
#               {'score': 0.10067027807235718,
#                'token': 2060,
#                'token_str': 'other',
#                'sequence': "shouldn't you be over there with your other friends?"},
#               {'score': 0.08709819614887238,
#                'token': 2190,
#                'token_str': 'best',
#                'sequence': "shouldn't you be over there with your best friends?"},
#               {'score': 0.06691211462020874,
#                'token': 2214,
#                'token_str': 'old',
#                'sequence': "shouldn't you be over there with your old friends?"},
#               {'score': 0.03306974843144417,
#                'token': 2210,
#                'token_str': 'little',
#                'sequence': "shouldn't you be over there with your little friends?"}],
#              '626': [{'score': 0.1554919183254242,
#                'token': 2034,
#                'token_str': 'first',
#                'sequence': "it's the first rule."},
#               {'score': 0.09890979528427124,
#                'token': 2236,
#                'token_str': 'general',
#                'sequence': "it's the general rule."},
#               {'score': 0.09485013782978058,
#                'token': 2069,
#                'token_str': 'only',
#                'sequence': "it's the only rule."},
#               {'score': 0.09169168770313263,
#                'token': 3585,
#                'token_str': 'golden',
#                'sequence': "it's the golden rule."},
#               {'score': 0.05923737213015556,
#                'token': 25982,
#                'token_str': 'unspoken',
#                'sequence': "it's the unspoken rule."}],
#              '638': [{'score': 0.9077253937721252,
#                'token': 2000,
#                'token_str': 'to',
#                'sequence': "do you think they'll try to attack?"},
#               {'score': 0.03960779309272766,
#                'token': 2019,
#                'token_str': 'an',
#                'sequence': "do you think they'll try an attack?"},
#               {'score': 0.029889261350035667,
#                'token': 1998,
#                'token_str': 'and',
#                'sequence': "do you think they'll try and attack?"},
#               {'score': 0.014261022210121155,
#                'token': 2178,
#                'token_str': 'another',
#                'sequence': "do you think they'll try another attack?"},
#               {'score': 0.003878707066178322,
#                'token': 1996,
#                'token_str': 'the',
#                'sequence': "do you think they'll try the attack?"}],
#              '669': [{'score': 0.4679732620716095,
#                'token': 2019,
#                'token_str': 'an',
#                'sequence': "plus, they're scared about an attack."},
#               {'score': 0.3768984079360962,
#                'token': 1996,
#                'token_str': 'the',
#                'sequence': "plus, they're scared about the attack."},
#               {'score': 0.08014222234487534,
#                'token': 2178,
#                'token_str': 'another',
#                'sequence': "plus, they're scared about another attack."},
#               {'score': 0.027730872854590416,
#                'token': 2256,
#                'token_str': 'our',
#                'sequence': "plus, they're scared about our attack."},
#               {'score': 0.012939787469804287,
#                'token': 2023,
#                'token_str': 'this',
#                'sequence': "plus, they're scared about this attack."}],
#              '1758': [{'score': 0.2799898684024811,
#                'token': 3752,
#                'token_str': 'reading',
#                'sequence': 'and they bust my reading glasses.'},
#               {'score': 0.070709228515625,
#                'token': 3239,
#                'token_str': 'eye',
#                'sequence': 'and they bust my eye glasses.'},
#               {'score': 0.06946612149477005,
#                'token': 2601,
#                'token_str': 'dark',
#                'sequence': 'and they bust my dark glasses.'},
#               {'score': 0.05645321309566498,
#                'token': 2219,
#                'token_str': 'own',
#                'sequence': 'and they bust my own glasses.'},
#               {'score': 0.01961466483771801,
#                'token': 20422,
#                'token_str': 'prescription',
#                'sequence': 'and they bust my prescription glasses.'}],
#              '2089': [{'score': 0.03233974799513817,
#                'token': 3674,
#                'token_str': 'multiple',
#                'sequence': 'multiple identities.'},
#               {'score': 0.032148972153663635,
#                'token': 3795,
#                'token_str': 'global',
#                'sequence': 'global identities.'},
#               {'score': 0.02932259812951088,
#                'token': 2529,
#                'token_str': 'human',
#                'sequence': 'human identities.'},
#               {'score': 0.018301544710993767,
#                'token': 3451,
#                'token_str': 'cultural',
#                'sequence': 'cultural identities.'},
#               {'score': 0.018092457205057144,
#                'token': 3167,
#                'token_str': 'personal',
#                'sequence': 'personal identities.'}],
#              '2208': [{'score': 0.29171261191368103,
#                'token': 1045,
#                'token_str': 'i',
#                'sequence': 'i hope.'},
#               {'score': 0.06157566234469414,
#                'token': 2053,
#                'token_str': 'no',
#                'sequence': 'no hope.'},
#               {'score': 0.03788232058286667,
#                'token': 1998,
#                'token_str': 'and',
#                'sequence': 'and hope.'},
#               {'score': 0.03715692460536957,
#                'token': 1996,
#                'token_str': 'the',
#                'sequence': 'the hope.'},
#               {'score': 0.02278343215584755,
#                'token': 2000,
#                'token_str': 'to',
#                'sequence': 'to hope.'}],
#              '2209': [{'score': 0.08553313463926315,
#                'token': 1996,
#                'token_str': 'the',
#                'sequence': 'the house.'},
#               {'score': 0.0258155707269907,
#                'token': 1037,
#                'token_str': 'a',
#                'sequence': 'a house.'},
#               {'score': 0.017985505983233452,
#                'token': 2317,
#                'token_str': 'white',
#                'sequence': 'white house.'},
#               {'score': 0.014419524930417538,
#                'token': 9118,
#                'token_str': 'carriage',
#                'sequence': 'carriage house.'},
#               {'score': 0.013162669725716114,
#                'token': 4157,
#                'token_str': 'coffee',
#                'sequence': 'coffee house.'}],
#              '2330': [{'score': 0.7307668328285217,
#                'token': 14751,
#                'token_str': 'newest',
#                'sequence': 'class, this is our newest student, allison argent.'},
#               {'score': 0.09372646361589432,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': 'class, this is our new student, allison argent.'},
#               {'score': 0.01491361390799284,
#                'token': 2034,
#                'token_str': 'first',
#                'sequence': 'class, this is our first student, allison argent.'},
#               {'score': 0.012584047392010689,
#                'token': 2783,
#                'token_str': 'current',
#                'sequence': 'class, this is our current student, allison argent.'},
#               {'score': 0.011156451888382435,
#                'token': 6745,
#                'token_str': 'latest',
#                'sequence': 'class, this is our latest student, allison argent.'}],
#              '2778': [{'score': 0.512438178062439,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': "i'm all about discovering new talents."},
#               {'score': 0.3100959360599518,
#                'token': 2026,
#                'token_str': 'my',
#                'sequence': "i'm all about discovering my talents."},
#               {'score': 0.07470197975635529,
#                'token': 2115,
#                'token_str': 'your',
#                'sequence': "i'm all about discovering your talents."},
#               {'score': 0.009623448364436626,
#                'token': 2060,
#                'token_str': 'other',
#                'sequence': "i'm all about discovering other talents."},
#               {'score': 0.008578021079301834,
#                'token': 2037,
#                'token_str': 'their',
#                'sequence': "i'm all about discovering their talents."}],
#              '3148': [{'score': 0.40886133909225464,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': "i find out something new about her every day, it seems like, and it's a pretty big thing that i would've never expected out of her."},
#               {'score': 0.1692800521850586,
#                'token': 2842,
#                'token_str': 'else',
#                'sequence': "i find out something else about her every day, it seems like, and it's a pretty big thing that i would've never expected out of her."},
#               {'score': 0.11676018685102463,
#                'token': 2367,
#                'token_str': 'different',
#                'sequence': "i find out something different about her every day, it seems like, and it's a pretty big thing that i would've never expected out of her."},
#               {'score': 0.07983490824699402,
#                'token': 2062,
#                'token_str': 'more',
#                'sequence': "i find out something more about her every day, it seems like, and it's a pretty big thing that i would've never expected out of her."},
#               {'score': 0.03628923371434212,
#                'token': 5875,
#                'token_str': 'interesting',
#                'sequence': "i find out something interesting about her every day, it seems like, and it's a pretty big thing that i would've never expected out of her."}],
#              '5011': [{'score': 0.7191805839538574,
#                'token': 1010,
#                'token_str': ',',
#                'sequence': "hey, easy woman! usually, when you spend a night at a man's house, shouldn't you easily give him your number, and ask when you can meet him, and make your time easily available?"},
#               {'score': 0.13917109370231628,
#                'token': 2045,
#                'token_str': 'there',
#                'sequence': "hey, easy woman! usually, when you spend a night at a man's house, shouldn't you easily give him your number, and ask when you can meet him there and make your time easily available?"},
#               {'score': 0.017383210361003876,
#                'token': 2182,
#                'token_str': 'here',
#                'sequence': "hey, easy woman! usually, when you spend a night at a man's house, shouldn't you easily give him your number, and ask when you can meet him here and make your time easily available?"},
#               {'score': 0.017073525115847588,
#                'token': 2133,
#                'token_str': '...',
#                'sequence': "hey, easy woman! usually, when you spend a night at a man's house, shouldn't you easily give him your number, and ask when you can meet him... and make your time easily available?"},
#               {'score': 0.016576644033193588,
#                'token': 2039,
#                'token_str': 'up',
#                'sequence': "hey, easy woman! usually, when you spend a night at a man's house, shouldn't you easily give him your number, and ask when you can meet him up and make your time easily available?"}],
#              '5747': [{'score': 0.8746749758720398,
#                'token': 1996,
#                'token_str': 'the',
#                'sequence': 'aigo... the new magistrate knows nothing at all.'},
#               {'score': 0.04400724172592163,
#                'token': 2023,
#                'token_str': 'this',
#                'sequence': 'aigo... this new magistrate knows nothing at all.'},
#               {'score': 0.02890932746231556,
#                'token': 1037,
#                'token_str': 'a',
#                'sequence': 'aigo... a new magistrate knows nothing at all.'},
#               {'score': 0.017608514055609703,
#                'token': 2256,
#                'token_str': 'our',
#                'sequence': 'aigo... our new magistrate knows nothing at all.'},
#               {'score': 0.011568861082196236,
#                'token': 2008,
#                'token_str': 'that',
#                'sequence': 'aigo... that new magistrate knows nothing at all.'}],
#              '5749': [{'score': 0.3698751926422119,
#                'token': 2334,
#                'token_str': 'local',
#                'sequence': 'i would talk to the local magistrate about bang nap. ( preparing the tribute for people with some interest )'},
#               {'score': 0.11083658784627914,
#                'token': 2212,
#                'token_str': 'district',
#                'sequence': 'i would talk to the district magistrate about bang nap. ( preparing the tribute for people with some interest )'},
#               {'score': 0.05464500933885574,
#                'token': 2237,
#                'token_str': 'town',
#                'sequence': 'i would talk to the town magistrate about bang nap. ( preparing the tribute for people with some interest )'},
#               {'score': 0.05457085371017456,
#                'token': 2708,
#                'token_str': 'chief',
#                'sequence': 'i would talk to the chief magistrate about bang nap. ( preparing the tribute for people with some interest )'},
#               {'score': 0.04940038174390793,
#                'token': 2103,
#                'token_str': 'city',
#                'sequence': 'i would talk to the city magistrate about bang nap. ( preparing the tribute for people with some interest )'}],
#              '6239': [{'score': 0.3611007034778595,
#                'token': 2708,
#                'token_str': 'chief',
#                'sequence': 'i was worreid if they come to the office often as the chief magistrate is appointed.'},
#               {'score': 0.06663212925195694,
#                'token': 2334,
#                'token_str': 'local',
#                'sequence': 'i was worreid if they come to the office often as the local magistrate is appointed.'},
#               {'score': 0.05182149261236191,
#                'token': 2034,
#                'token_str': 'first',
#                'sequence': 'i was worreid if they come to the office often as the first magistrate is appointed.'},
#               {'score': 0.05131446197628975,
#                'token': 2212,
#                'token_str': 'district',
#                'sequence': 'i was worreid if they come to the office often as the district magistrate is appointed.'},
#               {'score': 0.042801178991794586,
#                'token': 2221,
#                'token_str': 'county',
#                'sequence': 'i was worreid if they come to the office often as the county magistrate is appointed.'}],
#              '6748': [{'score': 0.1393061876296997,
#                'token': 2708,
#                'token_str': 'chief',
#                'sequence': 'so you are the chief magistrate.'},
#               {'score': 0.09148634225130081,
#                'token': 2334,
#                'token_str': 'local',
#                'sequence': 'so you are the local magistrate.'},
#               {'score': 0.07758831232786179,
#                'token': 2237,
#                'token_str': 'town',
#                'sequence': 'so you are the town magistrate.'},
#               {'score': 0.04812617599964142,
#                'token': 2103,
#                'token_str': 'city',
#                'sequence': 'so you are the city magistrate.'},
#               {'score': 0.04694421961903572,
#                'token': 2221,
#                'token_str': 'county',
#                'sequence': 'so you are the county magistrate.'}],
#              '7201': [{'score': 0.8928040862083435,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': 'old power or new power...?'},
#               {'score': 0.03989218547940254,
#                'token': 2214,
#                'token_str': 'old',
#                'sequence': 'old power or old power...?'},
#               {'score': 0.015182546339929104,
#                'token': 2402,
#                'token_str': 'young',
#                'sequence': 'old power or young power...?'},
#               {'score': 0.0047286637127399445,
#                'token': 2715,
#                'token_str': 'modern',
#                'sequence': 'old power or modern power...?'},
#               {'score': 0.003450321964919567,
#                'token': 10947,
#                'token_str': 'newer',
#                'sequence': 'old power or newer power...?'}],
#              '7543': [{'score': 0.5943466424942017,
#                'token': 1996,
#                'token_str': 'the',
#                'sequence': 'in the trials, after the experience,'},
#               {'score': 0.07379535585641861,
#                'token': 6612,
#                'token_str': 'clinical',
#                'sequence': 'in clinical trials, after the experience,'},
#               {'score': 0.046860795468091965,
#                'token': 2122,
#                'token_str': 'these',
#                'sequence': 'in these trials, after the experience,'},
#               {'score': 0.034588295966386795,
#                'token': 2070,
#                'token_str': 'some',
#                'sequence': 'in some trials, after the experience,'},
#               {'score': 0.014462601393461227,
#                'token': 2119,
#                'token_str': 'both',
#                'sequence': 'in both trials, after the experience,'}],
#              '9295': [{'score': 0.1825823038816452,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': 'everyone, dr. jeremy bishop, our new gen - surg on staff.'},
#               {'score': 0.11657562851905823,
#                'token': 14751,
#                'token_str': 'newest',
#                'sequence': 'everyone, dr. jeremy bishop, our newest gen - surg on staff.'},
#               {'score': 0.10821523517370224,
#                'token': 2034,
#                'token_str': 'first',
#                'sequence': 'everyone, dr. jeremy bishop, our first gen - surg on staff.'},
#               {'score': 0.029553042724728584,
#                'token': 2783,
#                'token_str': 'current',
#                'sequence': 'everyone, dr. jeremy bishop, our current gen - surg on staff.'},
#               {'score': 0.02392404153943062,
#                'token': 2280,
#                'token_str': 'former',
#                'sequence': 'everyone, dr. jeremy bishop, our former gen - surg on staff.'}],
#              '9345': [{'score': 0.9006475806236267,
#                'token': 3043,
#                'token_str': 'matter',
#                'sequence': "what's the matter, dawson?"},
#               {'score': 0.02715674228966236,
#                'token': 3066,
#                'token_str': 'deal',
#                'sequence': "what's the deal, dawson?"},
#               {'score': 0.019884446635842323,
#                'token': 3291,
#                'token_str': 'problem',
#                'sequence': "what's the problem, dawson?"},
#               {'score': 0.010713115334510803,
#                'token': 2933,
#                'token_str': 'plan',
#                'sequence': "what's the plan, dawson?"},
#               {'score': 0.00868374016135931,
#                'token': 2391,
#                'token_str': 'point',
#                'sequence': "what's the point, dawson?"}],
#              '10010': [{'score': 0.13250911235809326,
#                'token': 22855,
#                'token_str': 'penthouse',
#                'sequence': '" mr. young, i know that you have your choice of law firms " to represent you in this matter " of josh moving into a penthouse apartment with his hot girlfriend... " no!'},
#               {'score': 0.10833453387022018,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': '" mr. young, i know that you have your choice of law firms " to represent you in this matter " of josh moving into a new apartment with his hot girlfriend... " no!'},
#               {'score': 0.09737484157085419,
#                'token': 2235,
#                'token_str': 'small',
#                'sequence': '" mr. young, i know that you have your choice of law firms " to represent you in this matter " of josh moving into a small apartment with his hot girlfriend... " no!'},
#               {'score': 0.05830492451786995,
#                'token': 4714,
#                'token_str': 'tiny',
#                'sequence': '" mr. young, i know that you have your choice of law firms " to represent you in this matter " of josh moving into a tiny apartment with his hot girlfriend... " no!'},
#               {'score': 0.0376947820186615,
#                'token': 11281,
#                'token_str': 'fancy',
#                'sequence': '" mr. young, i know that you have your choice of law firms " to represent you in this matter " of josh moving into a fancy apartment with his hot girlfriend... " no!'}],
#              '10127': [{'score': 0.16249974071979523,
#                'token': 2210,
#                'token_str': 'little',
#                'sequence': "listen, you better get your act together, young lady, or you're gonna run this little life off in the ditch."},
#               {'score': 0.054509058594703674,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': "listen, you better get your act together, young lady, or you're gonna run this new life off in the ditch."},
#               {'score': 0.046152263879776,
#                'token': 17203,
#                'token_str': 'pathetic',
#                'sequence': "listen, you better get your act together, young lady, or you're gonna run this pathetic life off in the ditch."},
#               {'score': 0.038711514323949814,
#                'token': 2214,
#                'token_str': 'old',
#                'sequence': "listen, you better get your act together, young lady, or you're gonna run this old life off in the ditch."},
#               {'score': 0.037698909640312195,
#                'token': 3492,
#                'token_str': 'pretty',
#                'sequence': "listen, you better get your act together, young lady, or you're gonna run this pretty life off in the ditch."}],
#              '10558': [{'score': 0.3798636496067047,
#                'token': 5440,
#                'token_str': 'favorite',
#                'sequence': "it's your favorite dining room table."},
#               {'score': 0.14210030436515808,
#                'token': 2214,
#                'token_str': 'old',
#                'sequence': "it's your old dining room table."},
#               {'score': 0.043335746973752975,
#                'token': 2210,
#                'token_str': 'little',
#                'sequence': "it's your little dining room table."},
#               {'score': 0.03893808275461197,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': "it's your new dining room table."},
#               {'score': 0.030351903289556503,
#                'token': 5156,
#                'token_str': 'usual',
#                'sequence': "it's your usual dining room table."}],
#              '10661': [{'score': 0.6248956322669983,
#                'token': 2878,
#                'token_str': 'whole',
#                'sequence': 'uh, hey, um, do you want to come over sometime, just check out the whole place?'},
#               {'score': 0.04351021349430084,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': 'uh, hey, um, do you want to come over sometime, just check out the new place?'},
#               {'score': 0.02672242745757103,
#                'token': 2214,
#                'token_str': 'old',
#                'sequence': 'uh, hey, um, do you want to come over sometime, just check out the old place?'},
#               {'score': 0.023082144558429718,
#                'token': 2972,
#                'token_str': 'entire',
#                'sequence': 'uh, hey, um, do you want to come over sometime, just check out the entire place?'},
#               {'score': 0.014706883579492569,
#                'token': 2060,
#                'token_str': 'other',
#                'sequence': 'uh, hey, um, do you want to come over sometime, just check out the other place?'}],
#              '10987': [{'score': 0.9630860686302185,
#                'token': 2197,
#                'token_str': 'last',
#                'sequence': "no, actually that's from last month's glamor."},
#               {'score': 0.013100978918373585,
#                'token': 2023,
#                'token_str': 'this',
#                'sequence': "no, actually that's from this month's glamor."},
#               {'score': 0.007409342564642429,
#                'token': 1996,
#                'token_str': 'the',
#                'sequence': "no, actually that's from the month's glamor."},
#               {'score': 0.00705549493432045,
#                'token': 1037,
#                'token_str': 'a',
#                'sequence': "no, actually that's from a month's glamor."},
#               {'score': 0.0027211110573261976,
#                'token': 2008,
#                'token_str': 'that',
#                'sequence': "no, actually that's from that month's glamor."}],
#              '11659': [{'score': 0.23055066168308258,
#                'token': 2037,
#                'token_str': 'their',
#                'sequence': 'brand - new pals and their career'},
#               {'score': 0.18189404904842377,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': 'brand - new pals and new career'},
#               {'score': 0.09494754672050476,
#                'token': 1037,
#                'token_str': 'a',
#                'sequence': 'brand - new pals and a career'},
#               {'score': 0.039473216980695724,
#                'token': 2925,
#                'token_str': 'future',
#                'sequence': 'brand - new pals and future career'},
#               {'score': 0.03257112205028534,
#                'token': 2026,
#                'token_str': 'my',
#                'sequence': 'brand - new pals and my career'}],
#              '12495': [{'score': 0.1723669171333313,
#                'token': 3492,
#                'token_str': 'pretty',
#                'sequence': "yeah, i'm trying this really pretty radical approach to studying..."},
#               {'score': 0.13990537822246552,
#                'token': 2428,
#                'token_str': 'really',
#                'sequence': "yeah, i'm trying this really really radical approach to studying..."},
#               {'score': 0.11826895922422409,
#                'token': 2062,
#                'token_str': 'more',
#                'sequence': "yeah, i'm trying this really more radical approach to studying..."},
#               {'score': 0.07797116786241531,
#                'token': 2200,
#                'token_str': 'very',
#                'sequence': "yeah, i'm trying this really very radical approach to studying..."},
#               {'score': 0.0645439624786377,
#                'token': 2133,
#                'token_str': '...',
#                'sequence': "yeah, i'm trying this really... radical approach to studying..."}],
#              '12643': [{'score': 0.08535464853048325,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': "oh, well, we're just celebrating - a big new purchase."},
#               {'score': 0.0725320428609848,
#                'token': 2449,
#                'token_str': 'business',
#                'sequence': "oh, well, we're just celebrating - a big business purchase."},
#               {'score': 0.04055820778012276,
#                'token': 4234,
#                'token_str': 'christmas',
#                'sequence': "oh, well, we're just celebrating - a big christmas purchase."},
#               {'score': 0.022723976522684097,
#                'token': 2160,
#                'token_str': 'house',
#                'sequence': "oh, well, we're just celebrating - a big house purchase."},
#               {'score': 0.022478315979242325,
#                'token': 2155,
#                'token_str': 'family',
#                'sequence': "oh, well, we're just celebrating - a big family purchase."}],
#              '12645': [{'score': 0.393390417098999,
#                'token': 2210,
#                'token_str': 'little',
#                'sequence': 'josh just bought a sweet little car.'},
#               {'score': 0.1100177988409996,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': 'josh just bought a sweet new car.'},
#               {'score': 0.055910371243953705,
#                'token': 2417,
#                'token_str': 'red',
#                'sequence': 'josh just bought a sweet red car.'},
#               {'score': 0.042425528168678284,
#                'token': 5061,
#                'token_str': 'pink',
#                'sequence': 'josh just bought a sweet pink car.'},
#               {'score': 0.03831380233168602,
#                'token': 2559,
#                'token_str': 'looking',
#                'sequence': 'josh just bought a sweet looking car.'}],
#              '12820': [{'score': 0.4424647092819214,
#                'token': 2009,
#                'token_str': 'it',
#                'sequence': "- i can't afford it."},
#               {'score': 0.2619142532348633,
#                'token': 2008,
#                'token_str': 'that',
#                'sequence': "- i can't afford that."},
#               {'score': 0.09650599211454391,
#                'token': 2023,
#                'token_str': 'this',
#                'sequence': "- i can't afford this."},
#               {'score': 0.04959432780742645,
#                'token': 2000,
#                'token_str': 'to',
#                'sequence': "- i can't afford to."},
#               {'score': 0.027656642720103264,
#                'token': 2068,
#                'token_str': 'them',
#                'sequence': "- i can't afford them."}],
#              '13027': [{'score': 0.23642414808273315,
#                'token': 4365,
#                'token_str': 'damn',
#                'sequence': 'yeah, i do most of the time, but my damn car just exploded!'},
#               {'score': 0.10690377652645111,
#                'token': 2214,
#                'token_str': 'old',
#                'sequence': 'yeah, i do most of the time, but my old car just exploded!'},
#               {'score': 0.08174894005060196,
#                'token': 2878,
#                'token_str': 'whole',
#                'sequence': 'yeah, i do most of the time, but my whole car just exploded!'},
#               {'score': 0.06098616123199463,
#                'token': 2219,
#                'token_str': 'own',
#                'sequence': 'yeah, i do most of the time, but my own car just exploded!'},
#               {'score': 0.0476093553006649,
#                'token': 5236,
#                'token_str': 'stupid',
#                'sequence': 'yeah, i do most of the time, but my stupid car just exploded!'}],
#              '13056': [{'score': 0.17165854573249817,
#                'token': 2502,
#                'token_str': 'big',
#                'sequence': "long story short, your son stole our stuff and then blew up my brother's big, fully - loaded suv."},
#               {'score': 0.09012892842292786,
#                'token': 2214,
#                'token_str': 'old',
#                'sequence': "long story short, your son stole our stuff and then blew up my brother's old, fully - loaded suv."},
#               {'score': 0.08222509175539017,
#                'token': 4121,
#                'token_str': 'huge',
#                'sequence': "long story short, your son stole our stuff and then blew up my brother's huge, fully - loaded suv."},
#               {'score': 0.0724632516503334,
#                'token': 2304,
#                'token_str': 'black',
#                'sequence': "long story short, your son stole our stuff and then blew up my brother's black, fully - loaded suv."},
#               {'score': 0.05830832198262215,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': "long story short, your son stole our stuff and then blew up my brother's new, fully - loaded suv."}],
#              '13453': [{'score': 0.21804872155189514,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': 'automated voice : you have one new message.'},
#               {'score': 0.19838005304336548,
#                'token': 2062,
#                'token_str': 'more',
#                'sequence': 'automated voice : you have one more message.'},
#               {'score': 0.16134428977966309,
#                'token': 2197,
#                'token_str': 'last',
#                'sequence': 'automated voice : you have one last message.'},
#               {'score': 0.044554512947797775,
#                'token': 2060,
#                'token_str': 'other',
#                'sequence': 'automated voice : you have one other message.'},
#               {'score': 0.033849965780973434,
#                'token': 4771,
#                'token_str': 'missed',
#                'sequence': 'automated voice : you have one missed message.'}],
#              '13560': [{'score': 0.11656416207551956,
#                'token': 2210,
#                'token_str': 'little',
#                'sequence': 'oh! i just thought of a little joke.'},
#               {'score': 0.10678976774215698,
#                'token': 6057,
#                'token_str': 'funny',
#                'sequence': 'oh! i just thought of a funny joke.'},
#               {'score': 0.10458823293447495,
#                'token': 2204,
#                'token_str': 'good',
#                'sequence': 'oh! i just thought of a good joke.'},
#               {'score': 0.07206935435533524,
#                'token': 6742,
#                'token_str': 'practical',
#                'sequence': 'oh! i just thought of a practical joke.'},
#               {'score': 0.05764772742986679,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': 'oh! i just thought of a new joke.'}],
#              '14382': [{'score': 0.6838253736495972,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': "i'm making a new rule."},
#               {'score': 0.032403238117694855,
#                'token': 2204,
#                'token_str': 'good',
#                'sequence': "i'm making a good rule."},
#               {'score': 0.015515715815126896,
#                'token': 3722,
#                'token_str': 'simple',
#                'sequence': "i'm making a simple rule."},
#               {'score': 0.014783795922994614,
#                'token': 2502,
#                'token_str': 'big',
#                'sequence': "i'm making a big rule."},
#               {'score': 0.014424235559999943,
#                'token': 5236,
#                'token_str': 'stupid',
#                'sequence': "i'm making a stupid rule."}],
#              '14439': [{'score': 0.7733592987060547,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': "it's a whole new game of soldiers with their artificial arms."},
#               {'score': 0.0851786732673645,
#                'token': 2060,
#                'token_str': 'other',
#                'sequence': "it's a whole other game of soldiers with their artificial arms."},
#               {'score': 0.05380334332585335,
#                'token': 2367,
#                'token_str': 'different',
#                'sequence': "it's a whole different game of soldiers with their artificial arms."},
#               {'score': 0.009182441048324108,
#                'token': 2210,
#                'token_str': 'little',
#                'sequence': "it's a whole little game of soldiers with their artificial arms."},
#               {'score': 0.005683592054992914,
#                'token': 2214,
#                'token_str': 'old',
#                'sequence': "it's a whole old game of soldiers with their artificial arms."}],
#              '14480': [{'score': 0.8054436445236206,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': "it's a chance to practise our public speaking and learn new things."},
#               {'score': 0.05381612852215767,
#                'token': 2070,
#                'token_str': 'some',
#                'sequence': "it's a chance to practise our public speaking and learn some things."},
#               {'score': 0.02013961412012577,
#                'token': 2122,
#                'token_str': 'these',
#                'sequence': "it's a chance to practise our public speaking and learn these things."},
#               {'score': 0.018847526982426643,
#                'token': 2116,
#                'token_str': 'many',
#                'sequence': "it's a chance to practise our public speaking and learn many things."},
#               {'score': 0.018453270196914673,
#                'token': 2060,
#                'token_str': 'other',
#                'sequence': "it's a chance to practise our public speaking and learn other things."}],
#              '14656': [{'score': 0.9999916553497314,
#                'token': 6846,
#                'token_str': 'nova',
#                'sequence': 'dustin and sasha from halifax, nova scotia.'},
#               {'score': 4.150149834458716e-06,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': 'dustin and sasha from halifax, new scotia.'},
#               {'score': 6.454300205405161e-07,
#                'token': 10475,
#                'token_str': 'halifax',
#                'sequence': 'dustin and sasha from halifax, halifax scotia.'},
#               {'score': 4.090874199391692e-07,
#                'token': 2329,
#                'token_str': 'british',
#                'sequence': 'dustin and sasha from halifax, british scotia.'},
#               {'score': 4.054001863096346e-07,
#                'token': 2225,
#                'token_str': 'west',
#                'sequence': 'dustin and sasha from halifax, west scotia.'}],
#              '14688': [{'score': 0.2210148274898529,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': "oh! and, uh, while i have you, if you could have macy's restock the new jordan 5's, size ten, that would be awesome."},
#               {'score': 0.03767062723636627,
#                'token': 3565,
#                'token_str': 'super',
#                'sequence': "oh! and, uh, while i have you, if you could have macy's restock the super jordan 5's, size ten, that would be awesome."},
#               {'score': 0.02539418451488018,
#                'token': 3434,
#                'token_str': 'louis',
#                'sequence': "oh! and, uh, while i have you, if you could have macy's restock the louis jordan 5's, size ten, that would be awesome."},
#               {'score': 0.019988534972071648,
#                'token': 2888,
#                'token_str': 'henry',
#                'sequence': "oh! and, uh, while i have you, if you could have macy's restock the henry jordan 5's, size ten, that would be awesome."},
#               {'score': 0.019664805382490158,
#                'token': 2280,
#                'token_str': 'former',
#                'sequence': "oh! and, uh, while i have you, if you could have macy's restock the former jordan 5's, size ten, that would be awesome."}],
#              '15136': [{'score': 0.9999680519104004,
#                'token': 6846,
#                'token_str': 'nova',
#                'sequence': "i'm not from nova scotia."},
#               {'score': 1.1193668797204737e-05,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': "i'm not from new scotia."},
#               {'score': 2.349047463212628e-06,
#                'token': 2167,
#                'token_str': 'north',
#                'sequence': "i'm not from north scotia."},
#               {'score': 2.0330242023192113e-06,
#                'token': 2642,
#                'token_str': 'northern',
#                'sequence': "i'm not from northern scotia."},
#               {'score': 1.982579760806402e-06,
#                'token': 5984,
#                'token_str': 'puerto',
#                'sequence': "i'm not from puerto scotia."}],
#              '16193': [{'score': 0.6541273593902588,
#                'token': 1011,
#                'token_str': '-',
#                'sequence': 'george, which of these dogs is likely to become - the - champion now?'},
#               {'score': 0.13609692454338074,
#                'token': 2088,
#                'token_str': 'world',
#                'sequence': 'george, which of these dogs is likely to become - the world champion now?'},
#               {'score': 0.018968332558870316,
#                'token': 2120,
#                'token_str': 'national',
#                'sequence': 'george, which of these dogs is likely to become - the national champion now?'},
#               {'score': 0.013236084021627903,
#                'token': 2034,
#                'token_str': 'first',
#                'sequence': 'george, which of these dogs is likely to become - the first champion now?'},
#               {'score': 0.01136801578104496,
#                'token': 4386,
#                'token_str': 'olympic',
#                'sequence': 'george, which of these dogs is likely to become - the olympic champion now?'}],
#              '16372': [{'score': 0.9999949932098389,
#                'token': 6846,
#                'token_str': 'nova',
#                'sequence': 'this is from an eleven - year - old girl in lunenberg, nova scotia.'},
#               {'score': 2.5414553874725243e-06,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': 'this is from an eleven - year - old girl in lunenberg, new scotia.'},
#               {'score': 3.3504286989227694e-07,
#                'token': 2225,
#                'token_str': 'west',
#                'sequence': 'this is from an eleven - year - old girl in lunenberg, west scotia.'},
#               {'score': 2.961164966563956e-07,
#                'token': 2329,
#                'token_str': 'british',
#                'sequence': 'this is from an eleven - year - old girl in lunenberg, british scotia.'},
#               {'score': 2.1371330660713284e-07,
#                'token': 28101,
#                'token_str': 'brit',
#                'sequence': 'this is from an eleven - year - old girl in lunenberg, brit scotia.'}],
#              '16606': [{'score': 0.11023805290460587,
#                'token': 5509,
#                'token_str': 'concrete',
#                'sequence': 'still, with no concrete evidence...'},
#               {'score': 0.0862324982881546,
#                'token': 2524,
#                'token_str': 'hard',
#                'sequence': 'still, with no hard evidence...'},
#               {'score': 0.06082596257328987,
#                'token': 5024,
#                'token_str': 'solid',
#                'sequence': 'still, with no solid evidence...'},
#               {'score': 0.05698397383093834,
#                'token': 4637,
#                'token_str': 'supporting',
#                'sequence': 'still, with no supporting evidence...'},
#               {'score': 0.05644720792770386,
#                'token': 3558,
#                'token_str': 'physical',
#                'sequence': 'still, with no physical evidence...'}],
#              '16796': [{'score': 0.6058152914047241,
#                'token': 4536,
#                'token_str': 'ride',
#                'sequence': 'of course the dog will need a ride home.'},
#               {'score': 0.08474353700876236,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': 'of course the dog will need a new home.'},
#               {'score': 0.02993045561015606,
#                'token': 2126,
#                'token_str': 'way',
#                'sequence': 'of course the dog will need a way home.'},
#               {'score': 0.016077395528554916,
#                'token': 8329,
#                'token_str': 'nursing',
#                'sequence': 'of course the dog will need a nursing home.'},
#               {'score': 0.013055145740509033,
#                'token': 5372,
#                'token_str': 'proper',
#                'sequence': 'of course the dog will need a proper home.'}],
#              '16884': [{'score': 0.15272285044193268,
#                'token': 2210,
#                'token_str': 'little',
#                'sequence': "tonight, for dinner, let's check out that little thai place."},
#               {'score': 0.15091247856616974,
#                'token': 2307,
#                'token_str': 'great',
#                'sequence': "tonight, for dinner, let's check out that great thai place."},
#               {'score': 0.10026819258928299,
#                'token': 2214,
#                'token_str': 'old',
#                'sequence': "tonight, for dinner, let's check out that old thai place."},
#               {'score': 0.0687672421336174,
#                'token': 11281,
#                'token_str': 'fancy',
#                'sequence': "tonight, for dinner, let's check out that fancy thai place."},
#               {'score': 0.05723879858851433,
#                'token': 3297,
#                'token_str': 'famous',
#                'sequence': "tonight, for dinner, let's check out that famous thai place."}],
#              '17376': [{'score': 0.42128074169158936,
#                'token': 2842,
#                'token_str': 'else',
#                'sequence': 'and then something else will begin.'},
#               {'score': 0.17993733286857605,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': 'and then something new will begin.'},
#               {'score': 0.05156077444553375,
#                'token': 2062,
#                'token_str': 'more',
#                'sequence': 'and then something more will begin.'},
#               {'score': 0.03404931351542473,
#                'token': 2204,
#                'token_str': 'good',
#                'sequence': 'and then something good will begin.'},
#               {'score': 0.027232438325881958,
#                'token': 2502,
#                'token_str': 'big',
#                'sequence': 'and then something big will begin.'}],
#              '17438': [{'score': 0.13721321523189545,
#                'token': 2137,
#                'token_str': 'american',
#                'sequence': 'posing the american flags.'},
#               {'score': 0.05278167873620987,
#                'token': 2120,
#                'token_str': 'national',
#                'sequence': 'posing the national flags.'},
#               {'score': 0.052755437791347504,
#                'token': 2417,
#                'token_str': 'red',
#                'sequence': 'posing the red flags.'},
#               {'score': 0.024042954668402672,
#                'token': 2665,
#                'token_str': 'green',
#                'sequence': 'posing the green flags.'},
#               {'score': 0.021141301840543747,
#                'token': 2317,
#                'token_str': 'white',
#                'sequence': 'posing the white flags.'}],
#              '17442': [{'score': 0.10607846826314926,
#                'token': 1996,
#                'token_str': 'the',
#                'sequence': 'religious ceremony for the flags.'},
#               {'score': 0.07385461032390594,
#                'token': 2120,
#                'token_str': 'national',
#                'sequence': 'religious ceremony for national flags.'},
#               {'score': 0.0350753553211689,
#                'token': 3909,
#                'token_str': 'flying',
#                'sequence': 'religious ceremony for flying flags.'},
#               {'score': 0.02788214571774006,
#                'token': 2048,
#                'token_str': 'two',
# ...
#                'token': 2317,
#                'token_str': 'white',
#                'sequence': "with a white coat, you'll be a new man."},
#               {'score': 0.016186363995075226,
#                'token': 2417,
#                'token_str': 'red',
#                'sequence': "with a red coat, you'll be a new man."},
#               {'score': 0.01587795466184616,
#                'token': 2304,
#                'token_str': 'black',
#                'sequence': "with a black coat, you'll be a new man."},
#               {'score': 0.014082108624279499,
#                'token': 6519,
#                'token_str': 'fur',
#                'sequence': "with a fur coat, you'll be a new man."}],
#              '376257': [{'score': 0.9711653590202332,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': "before you go to wish the mayor a happy new year, i'm informing you that you're invited to my house tonight."},
#               {'score': 0.003957471344619989,
#                'token': 2034,
#                'token_str': 'first',
#                'sequence': "before you go to wish the mayor a happy first year, i'm informing you that you're invited to my house tonight."},
#               {'score': 0.003035415429621935,
#                'token': 10807,
#                'token_str': 'fiscal',
#                'sequence': "before you go to wish the mayor a happy fiscal year, i'm informing you that you're invited to my house tonight."},
#               {'score': 0.0026184578891843557,
#                'token': 2082,
#                'token_str': 'school',
#                'sequence': "before you go to wish the mayor a happy school year, i'm informing you that you're invited to my house tonight."},
#               {'score': 0.0014989040791988373,
#                'token': 8094,
#                'token_str': 'calendar',
#                'sequence': "before you go to wish the mayor a happy calendar year, i'm informing you that you're invited to my house tonight."}],
#              '376261': [{'score': 0.173097163438797,
#                'token': 14185,
#                'token_str': 'trench',
#                'sequence': "that way, we'll christen mr. de carmine's trench coat."},
#               {'score': 0.12531974911689758,
#                'token': 6845,
#                'token_str': 'lab',
#                'sequence': "that way, we'll christen mr. de carmine's lab coat."},
#               {'score': 0.10024556517601013,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': "that way, we'll christen mr. de carmine's new coat."},
#               {'score': 0.08566814661026001,
#                'token': 4848,
#                'token_str': 'suit',
#                'sequence': "that way, we'll christen mr. de carmine's suit coat."},
#               {'score': 0.059271927922964096,
#                'token': 2317,
#                'token_str': 'white',
#                'sequence': "that way, we'll christen mr. de carmine's white coat."}],
#              '376277': [{'score': 0.1767360419034958,
#                'token': 2317,
#                'token_str': 'white',
#                'sequence': 'is he good at photographing white coats?'},
#               {'score': 0.07896409928798676,
#                'token': 2214,
#                'token_str': 'old',
#                'sequence': 'is he good at photographing old coats?'},
#               {'score': 0.0619489885866642,
#                'token': 1996,
#                'token_str': 'the',
#                'sequence': 'is he good at photographing the coats?'},
#               {'score': 0.06079123914241791,
#                'token': 2256,
#                'token_str': 'our',
#                'sequence': 'is he good at photographing our coats?'},
#               {'score': 0.05469875782728195,
#                'token': 6845,
#                'token_str': 'lab',
#                'sequence': 'is he good at photographing lab coats?'}],
#              '376394': [{'score': 0.9937645196914673,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': 'happy new year!'},
#               {'score': 0.0005919907125644386,
#                'token': 5798,
#                'token_str': 'birthday',
#                'sequence': 'happy birthday year!'},
#               {'score': 0.0004898746265098453,
#                'token': 2082,
#                'token_str': 'school',
#                'sequence': 'happy school year!'},
#               {'score': 0.000305284425849095,
#                'token': 10452,
#                'token_str': 'freshman',
#                'sequence': 'happy freshman year!'},
#               {'score': 0.00030457921093329787,
#                'token': 7665,
#                'token_str': 'graduation',
#                'sequence': 'happy graduation year!'}],
#              '376436': [{'score': 0.9995412826538086,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': "he's drunk, but it's new year's eve."},
#               {'score': 0.0001359839952783659,
#                'token': 3407,
#                'token_str': 'happy',
#                'sequence': "he's drunk, but it's happy year's eve."},
#               {'score': 5.934291402809322e-05,
#                'token': 2214,
#                'token_str': 'old',
#                'sequence': "he's drunk, but it's old year's eve."},
#               {'score': 5.463407433126122e-05,
#                'token': 2197,
#                'token_str': 'last',
#                'sequence': "he's drunk, but it's last year's eve."},
#               {'score': 1.986743518500589e-05,
#                'token': 2023,
#                'token_str': 'this',
#                'sequence': "he's drunk, but it's this year's eve."}],
#              '376437': [{'score': 0.9942333102226257,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': '- good night and happy new year.'},
#               {'score': 0.0008549841586500406,
#                'token': 2279,
#                'token_str': 'next',
#                'sequence': '- good night and happy next year.'},
#               {'score': 0.0006657848134636879,
#                'token': 2023,
#                'token_str': 'this',
#                'sequence': '- good night and happy this year.'},
#               {'score': 0.0006291776080615819,
#                'token': 2035,
#                'token_str': 'all',
#                'sequence': '- good night and happy all year.'},
#               {'score': 0.00022128949058242142,
#                'token': 1996,
#                'token_str': 'the',
#                'sequence': '- good night and happy the year.'}],
#              '376440': [{'score': 0.11436497420072556,
#                'token': 6519,
#                'token_str': 'fur',
#                'sequence': '- fur coat.'},
#               {'score': 0.09925206005573273,
#                'token': 2417,
#                'token_str': 'red',
#                'sequence': '- red coat.'},
#               {'score': 0.07424134761095047,
#                'token': 2317,
#                'token_str': 'white',
#                'sequence': '- white coat.'},
#               {'score': 0.049949921667575836,
#                'token': 14185,
#                'token_str': 'trench',
#                'sequence': '- trench coat.'},
#               {'score': 0.04367821291089058,
#                'token': 2146,
#                'token_str': 'long',
#                'sequence': '- long coat.'}],
#              '376443': [{'score': 0.9937645196914673,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': 'happy new year!'},
#               {'score': 0.0005919907125644386,
#                'token': 5798,
#                'token_str': 'birthday',
#                'sequence': 'happy birthday year!'},
#               {'score': 0.0004898746265098453,
#                'token': 2082,
#                'token_str': 'school',
#                'sequence': 'happy school year!'},
#               {'score': 0.000305284425849095,
#                'token': 10452,
#                'token_str': 'freshman',
#                'sequence': 'happy freshman year!'},
#               {'score': 0.00030457921093329787,
#                'token': 7665,
#                'token_str': 'graduation',
#                'sequence': 'happy graduation year!'}],
#              '376449': [{'score': 0.9911720156669617,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': 'happy new year.'},
#               {'score': 0.0006122965132817626,
#                'token': 2082,
#                'token_str': 'school',
#                'sequence': 'happy school year.'},
#               {'score': 0.0005627991631627083,
#                'token': 3407,
#                'token_str': 'happy',
#                'sequence': 'happy happy year.'},
#               {'score': 0.00047357697621919215,
#                'token': 5798,
#                'token_str': 'birthday',
#                'sequence': 'happy birthday year.'},
#               {'score': 0.0002943724684882909,
#                'token': 5030,
#                'token_str': 'wedding',
#                'sequence': 'happy wedding year.'}],
#              '376450': [{'score': 0.9937645196914673,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': 'happy new year!'},
#               {'score': 0.0005919907125644386,
#                'token': 5798,
#                'token_str': 'birthday',
#                'sequence': 'happy birthday year!'},
#               {'score': 0.0004898746265098453,
#                'token': 2082,
#                'token_str': 'school',
#                'sequence': 'happy school year!'},
#               {'score': 0.000305284425849095,
#                'token': 10452,
#                'token_str': 'freshman',
#                'sequence': 'happy freshman year!'},
#               {'score': 0.00030457921093329787,
#                'token': 7665,
#                'token_str': 'graduation',
#                'sequence': 'happy graduation year!'}],
#              '376463': [{'score': 0.3827023506164551,
#                'token': 2304,
#                'token_str': 'black',
#                'sequence': 'it was black, with a fur trim.'},
#               {'score': 0.15522144734859467,
#                'token': 2317,
#                'token_str': 'white',
#                'sequence': 'it was white, with a fur trim.'},
#               {'score': 0.03856746479868889,
#                'token': 2829,
#                'token_str': 'brown',
#                'sequence': 'it was brown, with a fur trim.'},
#               {'score': 0.027604805305600166,
#                'token': 2601,
#                'token_str': 'dark',
#                'sequence': 'it was dark, with a fur trim.'},
#               {'score': 0.02744748257100582,
#                'token': 2460,
#                'token_str': 'short',
#                'sequence': 'it was short, with a fur trim.'}],
#              '376527': [{'score': 0.178227961063385,
#                'token': 2214,
#                'token_str': 'old',
#                'sequence': "well, my coat's been stolen, my old coat. yes, the one with the fur trim."},
#               {'score': 0.1537630409002304,
#                'token': 6519,
#                'token_str': 'fur',
#                'sequence': "well, my coat's been stolen, my fur coat. yes, the one with the fur trim."},
#               {'score': 0.1045391634106636,
#                'token': 2219,
#                'token_str': 'own',
#                'sequence': "well, my coat's been stolen, my own coat. yes, the one with the fur trim."},
#               {'score': 0.0571565218269825,
#                'token': 3467,
#                'token_str': 'winter',
#                'sequence': "well, my coat's been stolen, my winter coat. yes, the one with the fur trim."},
#               {'score': 0.05600506067276001,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': "well, my coat's been stolen, my new coat. yes, the one with the fur trim."}],
#              '376627': [{'score': 0.7555407881736755,
#                'token': 1012,
#                'token_str': '.',
#                'sequence': 'this fortunate and ceremonious day underlines a decision that will bring our.'},
#               {'score': 0.14545877277851105,
#                'token': 1025,
#                'token_str': ';',
#                'sequence': 'this fortunate and ceremonious day underlines a decision that will bring our ;'},
#               {'score': 0.0388994924724102,
#                'token': 999,
#                'token_str': '!',
#                'sequence': 'this fortunate and ceremonious day underlines a decision that will bring our!'},
#               {'score': 0.02617812156677246,
#                'token': 1029,
#                'token_str': '?',
#                'sequence': 'this fortunate and ceremonious day underlines a decision that will bring our?'},
#               {'score': 0.010316632688045502,
#                'token': 2133,
#                'token_str': '...',
#                'sequence': 'this fortunate and ceremonious day underlines a decision that will bring our...'}],
#              '377592': [{'score': 0.12274240702390671,
#                'token': 2027,
#                'token_str': 'they',
#                'sequence': 'they lead for the second edition.'},
#               {'score': 0.10055699199438095,
#                'token': 1996,
#                'token_str': 'the',
#                'sequence': 'the lead for the second edition.'},
#               {'score': 0.016307968646287918,
#                'token': 2002,
#                'token_str': 'he',
#                'sequence': 'he lead for the second edition.'},
#               {'score': 0.012798049487173557,
#                'token': 2009,
#                'token_str': 'it',
#                'sequence': 'it lead for the second edition.'},
#               {'score': 0.012447643093764782,
#                'token': 2000,
#                'token_str': 'to',
#                'sequence': 'to lead for the second edition.'}],
#              '377723': [{'score': 0.9224981665611267,
#                'token': 2047,
#                'token_str': 'new',
#                'sequence': 'your husband created a new kind of journalism, and you helped him.'},
#               {'score': 0.02160724066197872,
#                'token': 2367,
#                'token_str': 'different',
#                'sequence': 'your husband created a different kind of journalism, and you helped him.'},
#               {'score': 0.01840180531144142,
#                'token': 4310,
#                'token_str': 'unique',
#                'sequence': 'your husband created a unique kind of journalism, and you helped him.'},
#               {'score': 0.00961048249155283,
#                'token': 2569,
#                'token_str': 'special',
#                'sequence': 'your husband created a special kind of journalism, and you helped him.'},
#               {'score': 0.00765996752306819,
#                'token': 2307,
#                'token_str': 'great',
#                'sequence': 'your husband created a great kind of journalism, and you helped him.'}],
#              '377766': [{'score': 0.8538578152656555,
#                'token': 1037,
#                'token_str': 'a',
#                'sequence': "quit now and look for a job or... wait for the probate judge's decision."},
#               {'score': 0.12844912707805634,
#                'token': 2178,
#                'token_str': 'another',
#                'sequence': "quit now and look for another job or... wait for the probate judge's decision."},
#               {'score': 0.006476118694990873,
#                'token': 2115,
#                'token_str': 'your',
#                'sequence': "quit now and look for your job or... wait for the probate judge's decision."},
#               {'score': 0.0061936331912875175,
#                'token': 1996,
#                'token_str': 'the',
#                'sequence': "quit now and look for the job or... wait for the probate judge's decision."},
#               {'score': 0.0008614828693680465,
#                'token': 2026,
#                'token_str': 'my',
#                'sequence': "quit now and look for my job or... wait for the probate judge's decision."}],
#              ...})

# %%
len(bert_word_dict.keys())
# Out:
# 2185

# %%
with open("corpora/subtitles/numerical_alignment/subtitles_inter.txt", "rt", encoding="utf-8") as file:
    aligned_inter = [[tuple(map(int, pair.split('-'))) for pair in line.strip().split()] for line in file]

with open("corpora/subtitles/numerical_alignment/subtitles_itermax.txt", "rt", encoding="utf-8") as file:
    aligned_itermax = [[tuple(map(int, pair.split('-'))) for pair in line.strip().split()] for line in file]

with open("corpora/subtitles/numerical_alignment/subtitles_mwmf.txt", "rt", encoding="utf-8") as file:
    aligned_mwmf = [[tuple(map(int, pair.split('-'))) for pair in line.strip().split()] for line in file]

with open("corpora/subtitles/translations/inter", "rt", encoding="utf-8") as file:
    t_aligned_inter = [[tuple(map(int, pair.split('-'))) for pair in line.strip().split()] for line in file]

with open("corpora/subtitles/translations/itermax", "rt", encoding="utf-8") as file:
    t_aligned_itermax = [[tuple(map(int, pair.split('-'))) for pair in line.strip().split()] for line in file]

with open("corpora/subtitles/translations/mwmf", "rt", encoding="utf-8") as file:
    t_aligned_mwmf = [[tuple(map(int, pair.split('-'))) for pair in line.strip().split()] for line in file]

# %%
ru_docs = ru_all_docs
en_docs = en_all_docs

# %%
import spacy
from spacy.tokens import DocBin
from collections import defaultdict
from tqdm import tqdm
import matplotlib.pyplot as plt
import numpy as np

import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords
ru_stopwords = [] # set(stopwords.words("russian"))
en_stopwords = [] # set(stopwords.words("english"))

# ru_stopwords.add('это')
# ru_stopwords.add('всё')
# ru_stopwords.add('свой')
# ru_stopwords.add('ещё')
# ru_stopwords.add('весь')

# en_stopwords.add("'s")

from string import punctuation
punct_list = [c for c in punctuation]
punct_list.append('--')
punct_list.append('...')
punct_list.append('–')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\warri\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def get_variety_dict_from_alignment(original_word: str, aligned_text: list, t_aligned_text: list):
    variety_dict = defaultdict(lambda : set())
    translation_dict = defaultdict(lambda : set())
    hell = []
    for i, num_sentence_pairs in tqdm(enumerate(aligned_text)):
        # if len(num_sentence_pairs) == 0 or len(en_translated_docs[i]) == 0:
        #     continue
        
        phrase = []
        for src_idx, tgt_idx in num_sentence_pairs:
            # try:
                if ru_docs[i][src_idx].lemma_.lower() == original_word \
                    and en_docs[i][tgt_idx].text.lower() not in en_stopwords \
                        and en_docs[i][tgt_idx].text.lower() not in punct_list:
                    phrase.append(en_docs[i][tgt_idx].lemma_.lower())

            # except:
            #     print("Original:", i, src_idx, tgt_idx)
            #     continue

        if phrase:
            # phrase.sort()
            # phrase = ' '.join(phrase)
            # variety_dict[phrase].add(i)

            translated_phrase = []
            for tsrc_idx, ttgt_idx in t_aligned_text[i]:
                # try:
                    tlemma = en_translated_docs[i][ttgt_idx].lemma_.lower()
                    if ru_docs[i][tsrc_idx].lemma_.lower() == original_word \
                        and tlemma not in en_stopwords \
                            and tlemma not in punct_list:
                        # translation_dict[tlemma].append(i)
                        translated_phrase.append(tlemma)
                # except:
                #     print("Translation:", i, tsrc_idx, ttgt_idx)
                #     continue
            
            if translated_phrase:
                phrase.sort()
                phrase = ' '.join(phrase)
                variety_dict[phrase].add(i)
                translated_phrase.sort()
                translated_phrase = ' '.join(translated_phrase)
                translation_dict[translated_phrase].add(i)
            else:
                hell.append(i)

    return variety_dict, translation_dict, hell

# %%
word = "работа"
orig, trans, hell = get_variety_dict_from_alignment(word, aligned_inter, t_aligned_inter)
# Out:
# 900000it [00:31, 28865.84it/s]

# %%
plot_variety_pie(trans, word)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 plot_variety_pie(trans, word)
#
# NameError: name 'plot_variety_pie' is not defined
